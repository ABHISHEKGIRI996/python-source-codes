# %%
def a(no):
    
    
    for i in range(no//2+1):
        
        for k in range(no//2-i,0,-1):
            print(end="  ")
        
        for j in range(2*i+1):
            
            if (i<no//2):
                if(j==0 or j==2*i):
                    print(end="* ")
                else:
                    print(end="  ")
            else:
                print(end="* ")
        print()
    
    for m in range(i,no):
        for n in range(no):
            
            if(n==0 or n==no-1):
                print(end="* ")
            else:
                print(end="  ")
        print()

# %%
def b(no):
    
    for i in range(no):
        
        for j in range(no//2+1):
            
            if (i==0 or i==no-1 or i==no//2):
                if (j==no//2):
                    print(end=" ")
                else:
                    print(end="* ")
            else:
                if(j==0 or j==no//2):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def c(no):
    
    for i in range(no):
        
        for j in range(no//2+3):
            
            if (i==0 or i==no-1):
                if (j==0 or j==no//2+2):
                    print(end="  ")
                else:
                    print(end="* ")
            elif(i==1 or i==no-2):
                
                if(j==0 or j==no//2):
                    print(end="* ")
                else:
                    print(end="    ")
            else:
                if(j==0):
                    print(end="*")
                else:
                    print(end=" ")
        print()

# %%
def d(no):
    
    for i in range(no):
        
        for j in range(no//2+1):
            
            if (i==0 or i==no-1):
                if (j==no//2):
                    print(end=" ")
                else:
                    print(end="* ")
            else:
                if(j==0 or j==no//2):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def e(no):
    
    for i in range(no):
        
        for j in range(no//2+1):
            
            if (i==0 or i==no-1 or i==no//2):
                print(end="* ")
            else:
                if(j==0):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def f(no):
    
    for i in range(no):
        
        for j in range(no//2+1):
            
            if (i==0):
                print(end="* ")
            elif(i==no//2):
                if(j==no//2):
                    print(end=" ")
                else:
                    print(end="* ")
            
            else:
                if(j==0):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def g(no):
    
    for i in range(no):
        
        for j in range(no//2+3):
            
            if (i==0 or i==no-1):
                if (j==0 or j==no//2+2):
                    print(end=" ")
                else:
                    print(end="* ")
            elif(i==1 or i>no//2):
                
                if(j==0 or j==no//2):
                    print(end="* ")
                else:
                    print(end="   ")
            elif(i==no//2):
                if((j>=(no//2+3)//2 and j<=no//2+2) or j==0):
                    print(end="* ")
                else:
                    print(end=" ")
            elif (i>=0 and i<no//2):
                if(j==0):
                    print(end="*")
                else:
                    print(end=" ")
#             else :
#                 if(j==0 or j==)
        print()

# %%
def h(no):
    
    for i in range(no):
        
        for j in range(no//2+2):
            
            if (i==no//2):
                print(end="* ")
            else:
                if(j==0 or j==no//2+1):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def i(no):
    
    for i in range(no):
        
        for j in range(no//2+2):
            
            if (i==0 or i==no-1):
                print(end="* ")
            else:
                if(j==(no//2+1)//2):
                    print(end="*")
                else:
                    print(end="  ")
        print()

# %%
def j(no):
    
    for i in range(no):
        
        for j in range(no//2+2):
            
            if (i==0):
                print(end="* ")
            
            elif(i==no-1):
                if(j>0 and j<(no//2+1)//2):
                    print(end="* ")
                else:
                    print(end="  ")
            
            elif(i<no-3):
                if(j==(no//2+1)//2):
                    print(end="*")
                else:
                    print(end="  ")
            else:
                if(j==(no//2+1)//2 or j==0):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def k(no):
    
    for i in range(no//2):
        for j in range(no//2+2,i+1,-1):
            if ( j==no//2+2 or j==i+2 ):

                print(end="* ")
            else:
                print(end=" ")
        if i==no//2+2:
            print(end="")
        else:
            print()


    for i in range (no//2):
        for j in range(i+4):
            if (j==0 or j==i+3):

                print(end="*")
            else:
                print(end=" ")
        print()

# %%
def l(no):
    
    for i in range(no):
        
        for j in range(no//2+1):
            
            if (i==no-1):
                print(end="* ")
            else:
                if(j==0):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def m(no):
    
    for i in range(no//2):
        
        for j in range(no-1):
            
            if (j== 0 or j==no-2 or i==j or j+i+2==no):
                print(end="* ")
            else:
                print(end="  ")
        print()
    
    for m in range(i,no-1):
        for n in range(no-1):
            
            if(n==0 or n==no-2):
                print(end="* ")
            else:
                print(end="  ")
        print()

# %%
def n(no):
    
    for i in range(no):
        
        for j in range(no):
            
            if (j== 0 or j==no-1 or i==j):
                print(end="* ")
            else:
                print(end="  ")
        print()

# %%
def o(no):
    
    for i in range(no):
        
        for j in range(no//2+3):
            
            if (i==0 or i==no-1):
                if (j==0 or j==no//2+2):
                    print(end="  ")
                else:
                    print(end="* ")
            else:
                if(j==0 or j==no//2+2):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def p(no):
    
    for i in range(no):
        
        for j in range(no//2+1):
            
            if (i==0 or i==no//2):
                if (j==no//2):
                    print(end=" ")
                else:
                    print(end="* ")
            elif(i<no//2):
                if(j==0 or j==no//2):
                    print(end="* ")
                else:
                    print(end="  ")
            else:
                if j==0:
                    print(end="*")
                else:
                    print(end=" ")
        print()

# %%
def q(no):
    
    for i in range(no):
        
        for j in range(no//2+3):
            
            if (i<no//2):
                if (i==0 or i==no-1):
                    if (j==0 or j==no//2+2):
                        print(end="  ")
                    else:
                        print(end="* ")
                else:
                    if(j==0 or j==no//2+2):
                        print(end="* ")
                    else:
                        print(end="  ")
            else :
                if (i==no-1):
                    if (j==0 or j==no//2+2):
                        print(end="  ")
                    else:
                        print(end="* ")
                else:
                    if (j==0 or j==no//2+2 or i==j):
                        print(end="* ")
                    else:
                        print(end="  ")
        
        
        
        print()

# %%
def p(no):
    
    for i in range(no//2+1):
        
        for j in range(no//2+1):
            
            if (i==0 or i==no//2):
                if (j==no//2):
                    print(end=" ")
                else:
                    print(end="* ")
            elif(i<no//2):
                if(j==0 or j==no//2):
                    print(end="* ")
                else:
                    print(end="  ")
        print()
    
    for i in range (no//2):
        for j in range(i+4):
            if (j==0 or j==i+3):

                print(end="*")
            else:
                print(end=" ")
        print()

# %%
def s(no):
    
    for i in range(no):
        
        for j in range(no//2+1):
            
            if (i==0 or i==no-1 or i==no//2):
                if (j==no//2 or j==0):
                    print(end="  ")
                else:
                    print(end="* ")
            
            elif(i==1 or i==no-2):
                if(j==0 or j==no//2):
                    print(end="* ")
                else:
                    print(end="  ")
                    
            elif(i>1 and i<no//2):
                if(j==0):
                    print(end="* ")
                else:
                    print(end="  ")
            else:
                if(j==no//2):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def t(no):
    
    for i in range(no):
        
        for j in range(no//2+2):
            
            if (i==0):
                print(end="* ")
            else:
                if(j==(no//2+1)//2):
                    print(end="*")
                else:
                    print(end="  ")
        print()

# %%
def u(no):
    
    for i in range(no):
        
        for j in range(no//2+3):
            
            if (i==no-1):
                if (j==0 or j==no//2+2):
                    print(end="  ")
                else:
                    print(end="* ")
            else:
                if(j==0 or j==no//2+2):
                    print(end="* ")
                else:
                    print(end="  ")
        print()

# %%
def v(no):
    
    for i in range(no):
        
        for j in range(no*2-1):
            
            if ( i==j or j+i+2==no*2):
                print(end="*")
            else:
                print(end=" ")
        print()

# %%
def w(no):
    
    
    
    for m in range(no//2):
        for n in range(no-1):
            
            if(n==0 or n==no-2):
                print(end="* ")
            else:
                print(end="  ")
        print()
    
    
    
    for i in range(m,no-1):
        
        for j in range(no-1):
            
            if (j== 0 or j==no-2 or i==j or j+i+2==no):
                print(end="* ")
            else:
                print(end="  ")
        print()

# %%
def x(no):
    
    for i in range(no):
        for j in range(no):
            if (i==j or i+j==no-1):
                print(end="* ")
            else:
                print(end="  ")
        print()

# %%
def y(no):
    
    for i in range(no//2):
        
        for j in range(no-1):
            
            if (i==j or j+i+2==no):
                print(end="* ")
            else:
                print(end="  ")
        print()
    
    for m in range(i,no-1):
        for n in range(no-1):
            
            if( n==no//2-1):
                print(end="* ")
            else:
                print(end="  ")
        print()

# %%
def z(no):
    
    for i in range(no):
        for j in range(no):
            
            if(i>0 and i<no-1):
                if (i+j==no-1):
                    print(end="* ")
                else:
                    print(end="  ")
            else:
                print(end="* ")
        print()

# %%
# MAIN BODY OF THE PROGRAM

# %%
print("-_"*10,"ALPHABET PRINTER","_-"*10)

ch=input("Enter a alphabet : ")
no = int(input("Enter size of the alphabet(integer) : "))
print()

if(ch=="a" or ch=="A"):
    a(no)
elif(ch=="b" or ch=="B"):
    b(no)
elif(ch=="c" or ch=="C"):
    c(no)
elif(ch=="d" or ch=="D"):
    d(no)
elif(ch=="e" or ch=="E"):
    e(no)
elif(ch=="f" or ch=="F"):
    f(no)
elif(ch=="g" or ch=="G"):
    g(no)
elif(ch=="h" or ch=="H"):
    h(no)
elif(ch=="i" or ch=="I"):
    i(no)
elif(ch=="j" or ch=="J"):
    J(no)
elif(ch=="k" or ch=="K"):
    k(no)
elif(ch=="l" or ch=="L"):
    l(no)
elif(ch=="m" or ch=="M"):
    m(no)
elif(ch=="n" or ch=="N"):
    n(no)
elif(ch=="o" or ch=="O"):
    o(no)
elif(ch=="p" or ch=="P"):
    p(no)
elif(ch=="q" or ch=="Q"):
    q(no)
elif(ch=="r" or ch=="R"):
    r(no)
elif(ch=="s" or ch=="S"):
    s(no)
elif(ch=="t" or ch=="T"):
    t(no)
elif(ch=="u" or ch=="U"):
    u(no)
elif(ch=="v" or ch=="V"):
    v(no)
elif(ch=="w" or ch=="W"):
    w(no)
elif(ch=="x" or ch=="X"):
    x(no)
elif(ch=="y" or ch=="Y"):
    y(no)
elif(ch=="z" or ch=="Z"):
    z(no)
else:
    print("INVALID INPUT !!!!!!!!!!")
# Out:
# -_-_-_-_-_-_-_-_-_-_ ALPHABET PRINTER _-_-_-_-_-_-_-_-_-_-
# Enter a alphabet : g
# Enter size of the alphabet(integer) : 7
#
#  * * * *
# *       *
# *
# *   * * *
# *       *
# *       *
#  * * * *
